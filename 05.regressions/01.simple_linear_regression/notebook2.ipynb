# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("simple_linear_regression.csv")

# %%
x = data["SAT"]
y = data["GPA"]
x_matrix = x.values.reshape(-1,1)

# %%
reg = LinearRegression()
reg.fit(x_matrix,y)
print("Intercept:", reg.intercept_)
print("Coefficient:", reg.coef_[0])
# Out:
# Intercept: 0.2750402996602799
# Coefficient: 0.0016556880500928142

# %%
r_squared = reg.score(x_matrix,y)
print("R Squared:", r_squared)
# Out:
# R Squared: 0.40600391479679754

# %%
predicted_gpa = reg.predict([[1700]])
print("Predicted GPA:", predicted_gpa[0])
# Out:
# Predicted GPA: 3.089709984818064

# %%
yhat = reg.coef_*x_matrix + reg.intercept_

# %%
plt.scatter(x,y)
fig = plt.plot(x, yhat, lw=4, c="orange", label="regression line")
plt.xlabel("SAT", fontsize=20)
plt.ylabel("GPA", fontsize=20)
plt.show()
